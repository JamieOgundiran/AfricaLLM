# %%
import csv
import re

data = """
|        Tasks        |Version|Filter|n-shot|Metric|   |Value |   |Stderr|
|---------------------|------:|------|-----:|------|---|-----:|---|------|
|afrixnli_amh_prompt_1|      1|none  |     0|acc   |↑  |0.3333|±  |0.0193|
|                     |       |none  |     0|f1    |↑  |0.1667|±  |   N/A|
|afrixnli_amh_prompt_2|      1|none  |     0|acc   |↑  |0.3950|±  |0.0200|
|                     |       |none  |     0|f1    |↑  |0.2982|±  |   N/A|
|afrixnli_amh_prompt_3|      1|none  |     0|acc   |↑  |0.3533|±  |0.0195|
|                     |       |none  |     0|f1    |↑  |0.3331|±  |   N/A|
|afrixnli_amh_prompt_4|      1|none  |     0|acc   |↑  |0.3883|±  |0.0199|
|                     |       |none  |     0|f1    |↑  |0.3852|±  |   N/A|
|afrixnli_amh_prompt_5|      1|none  |     0|acc   |↑  |0.3283|±  |0.0192|
|                     |       |none  |     0|f1    |↑  |0.1986|±  |   N/A|
|afrixnli_eng_prompt_1|      1|none  |     0|acc   |↑  |0.3333|±  |0.0193|
|                     |       |none  |     0|f1    |↑  |0.1667|±  |   N/A|
|afrixnli_eng_prompt_2|      1|none  |     0|acc   |↑  |0.5050|±  |0.0204|
|                     |       |none  |     0|f1    |↑  |0.4441|±  |   N/A|
|afrixnli_eng_prompt_3|      1|none  |     0|acc   |↑  |0.4150|±  |0.0201|
|                     |       |none  |     0|f1    |↑  |0.3436|±  |   N/A|
|afrixnli_eng_prompt_4|      1|none  |     0|acc   |↑  |0.4183|±  |0.0202|
|                     |       |none  |     0|f1    |↑  |0.3760|±  |   N/A|
|afrixnli_eng_prompt_5|      1|none  |     0|acc   |↑  |0.3617|±  |0.0196|
|                     |       |none  |     0|f1    |↑  |0.2362|±  |   N/A|
|afrixnli_ewe_prompt_1|      1|none  |     0|acc   |↑  |0.3333|±  |0.0193|
|                     |       |none  |     0|f1    |↑  |0.1667|±  |   N/A|
|afrixnli_ewe_prompt_2|      1|none  |     0|acc   |↑  |0.3583|±  |0.0196|
|                     |       |none  |     0|f1    |↑  |0.2681|±  |   N/A|
|afrixnli_ewe_prompt_3|      1|none  |     0|acc   |↑  |0.3633|±  |0.0197|
|                     |       |none  |     0|f1    |↑  |0.3163|±  |   N/A|
|afrixnli_ewe_prompt_4|      1|none  |     0|acc   |↑  |0.3583|±  |0.0196|
|                     |       |none  |     0|f1    |↑  |0.2927|±  |   N/A|
|afrixnli_ewe_prompt_5|      1|none  |     0|acc   |↑  |0.3350|±  |0.0193|
|                     |       |none  |     0|f1    |↑  |0.1702|±  |   N/A|
|afrixnli_fra_prompt_1|      1|none  |     0|acc   |↑  |0.3333|±  |0.0193|
|                     |       |none  |     0|f1    |↑  |0.1667|±  |   N/A|
|afrixnli_fra_prompt_2|      1|none  |     0|acc   |↑  |0.5100|±  |0.0204|
|                     |       |none  |     0|f1    |↑  |0.4653|±  |   N/A|
|afrixnli_fra_prompt_3|      1|none  |     0|acc   |↑  |0.4283|±  |0.0202|
|                     |       |none  |     0|f1    |↑  |0.3817|±  |   N/A|
|afrixnli_fra_prompt_4|      1|none  |     0|acc   |↑  |0.4083|±  |0.0201|
|                     |       |none  |     0|f1    |↑  |0.3651|±  |   N/A|
|afrixnli_fra_prompt_5|      1|none  |     0|acc   |↑  |0.3417|±  |0.0194|
|                     |       |none  |     0|f1    |↑  |0.1975|±  |   N/A|
|afrixnli_hau_prompt_1|      1|none  |     0|acc   |↑  |0.3333|±  |0.0193|
|                     |       |none  |     0|f1    |↑  |0.1667|±  |   N/A|
|afrixnli_hau_prompt_2|      1|none  |     0|acc   |↑  |0.3650|±  |0.0197|
|                     |       |none  |     0|f1    |↑  |0.2725|±  |   N/A|
|afrixnli_hau_prompt_3|      1|none  |     0|acc   |↑  |0.3200|±  |0.0191|
|                     |       |none  |     0|f1    |↑  |0.2746|±  |   N/A|
|afrixnli_hau_prompt_4|      1|none  |     0|acc   |↑  |0.3317|±  |0.0192|
|                     |       |none  |     0|f1    |↑  |0.2788|±  |   N/A|
|afrixnli_hau_prompt_5|      1|none  |     0|acc   |↑  |0.3333|±  |0.0193|
|                     |       |none  |     0|f1    |↑  |0.1671|±  |   N/A|
|afrixnli_ibo_prompt_1|      1|none  |     0|acc   |↑  |0.3333|±  |0.0193|
|                     |       |none  |     0|f1    |↑  |0.1667|±  |   N/A|
|afrixnli_ibo_prompt_2|      1|none  |     0|acc   |↑  |0.3650|±  |0.0197|
|                     |       |none  |     0|f1    |↑  |0
|                     |       |none  |     0|f1    |↑  |0.2861|±  |   N/A|
"""

# Clean the data and extract rows
lines = [line.strip() for line in data.split('\n') if line.strip()]
# Remove header and separator
lines = [line for line in lines if not set(line.strip()) <= {'|', '-'}]

# Get the header from the first row
header_line = lines[0]
all_headers = [h.strip() for h in header_line.strip('|').split('|')]
# Filter out empty headers (columns with no names like arrows and symbols)
headers = [h for h in all_headers if h]
# Remove the header row from lines
lines = lines[1:]

# Prepare rows
rows = []
last_task: str = ""
for line in lines:
    all_items = [item.strip() for item in line.strip('|').split('|')]
    # Filter out items corresponding to empty headers
    items = [all_items[i] for i in range(len(all_items)) if i < len(all_headers) and all_headers[i].strip()]
    
    # If the task column is empty, fill it with the last task name
    if items[0] == '':
        items[0] = last_task
    else:
        last_task = items[0]
    rows.append(items)

# Write to CSV
with open('output.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    writer.writerows(rows)

print("CSV file 'output.csv' created successfully.")
# Out:
# CSV file 'output.csv' created successfully.

# %%
import pandas as pd

df = pd.read_csv('output.csv')

# %%
df.head()
# Out:
#                    Tasks  Version  Filter  n-shot  Metric   Value  Stderr
# 0  ---------------------  ------:  ------  -----:  ------  -----:  ------
# 1  afrixnli_amh_prompt_1        1    none       0     acc  0.3333  0.0193
# 2  afrixnli_amh_prompt_1      NaN    none       0      f1  0.1667     NaN
# 3  afrixnli_amh_prompt_2        1    none       0     acc  0.3950  0.0200
# 4  afrixnli_amh_prompt_2      NaN    none       0      f1  0.2982     NaN

# %%
df = df[df['Filter'] != 'remove_whitespace']
df.head()
# Out:
#                    Tasks  Version  Filter  n-shot  Metric   Value  Stderr
# 0  ---------------------  ------:  ------  -----:  ------  -----:  ------
# 1  afrixnli_amh_prompt_1        1    none       0     acc  0.3333  0.0193
# 2  afrixnli_amh_prompt_1      NaN    none       0      f1  0.1667     NaN
# 3  afrixnli_amh_prompt_2        1    none       0     acc  0.3950  0.0200
# 4  afrixnli_amh_prompt_2      NaN    none       0      f1  0.2982     NaN

# %%
# Use inplace=True but don't assign the result
df.drop(columns=['Filter', 'n-shot', 'Version'], inplace=True)

# Now you can use df.head()
df.head()
# Out:
#                    Tasks  Metric   Value  Stderr
# 0  ---------------------  ------  -----:  ------
# 1  afrixnli_amh_prompt_1     acc  0.3333  0.0193
# 2  afrixnli_amh_prompt_1      f1  0.1667     NaN
# 3  afrixnli_amh_prompt_2     acc  0.3950  0.0200
# 4  afrixnli_amh_prompt_2      f1  0.2982     NaN

# %%
# Remove the first row (index 0)
df = df.iloc[1:]

# Show the result
df.head()
# Out:
#                    Tasks Metric   Value  Stderr
# 1  afrixnli_amh_prompt_1    acc  0.3333  0.0193
# 2  afrixnli_amh_prompt_1     f1  0.1667     NaN
# 3  afrixnli_amh_prompt_2    acc  0.3950  0.0200
# 4  afrixnli_amh_prompt_2     f1  0.2982     NaN
# 5  afrixnli_amh_prompt_3    acc  0.3533  0.0195

# %%
df.drop(columns=['Filter', 'n-shot', 'Version'], inplace=True)
